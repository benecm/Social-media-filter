# %%
result = [{'label': 'happy', 'score': 0.98}]

# %%
result
# Out:
# {'label': 'happy', 'score': 0.98}

# %%
from transformers import pipeline

# Initialize the sentiment analysis pipeline
sentiment_analyzer = pipeline("text-classification", model="Varnikasiva/sentiment-classification-bert-mini")

# Analyze text
text = "I feel okay today!"
result = sentiment_analyzer(text)
print(result)  # Output: [{'label': 'happy', 'score': 0.98}]
# Out:
# Device set to use cpu
# [{'label': 'happiness', 'score': 0.8578507900238037}]

# %%
result[0]['label']
# Out:
# 'happiness'

# %%
asd = "Awesome mega hit 2025🎇💨🤞🤙👍🚘"

# %%
import re
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

# %%
remove_emojis(asd)
# Out:
# 'Awesome mega hit 2025'

# %%
import pandas as pd

df = pd.read_json(r"C:\Users\Bence\Documents\GitHub\Social-media-filter\data\ground_truth_new.json")
print(df["Comment"].count())
print(df[df["Sentiment"]=="Positive"].count()[0])
print(df[df["Sentiment"]=="Neutral"].count()[0])
print(df[df["Sentiment"]=="Negative"].count()[0])
# Out:
# 100
# 30
# 35
# 35
# C:\Users\Bence\AppData\Local\Temp\ipykernel_8748\3362285782.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df[df["Sentiment"]=="Positive"].count()[0])
# C:\Users\Bence\AppData\Local\Temp\ipykernel_8748\3362285782.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df[df["Sentiment"]=="Neutral"].count()[0])
# ...

# %%
print(df[df["Prediction"]=="bot"].count()[0])
print(df[df["Prediction"]=="human"].count()[0])
# Out:
# 52
# 48
# C:\Users\Bence\AppData\Local\Temp\ipykernel_8748\3232935974.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df[df["Prediction"]=="bot"].count()[0])
# C:\Users\Bence\AppData\Local\Temp\ipykernel_8748\3232935974.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df[df["Prediction"]=="human"].count()[0])
